# %%
# 파일 생성하기
f = open("새파일.txt", "w")
f.close()

# %%
f = open("새파일2.txt", "w") # f는 파일 객체
for i in range(1,11):
    data = f"{i}번째 줄입니다.\n"
    f.write(data)
f.close()

# 인코딩 >> 127개의 문자 표현하는 ASCII code
